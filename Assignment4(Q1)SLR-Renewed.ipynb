# %%
#Q1.delivery_time

# %%
#Importing Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300
sns.set_theme(style='darkgrid')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/KJanhavi2424/My-Datasets/main/delivery_time.csv')
df
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
df.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
#Skew, kurt, mean, median, mode, min, max, var

# %%
df['Sorting Time'].skew()
# Out:
# 0.047115474210530174

# %%
df['Sorting Time'].kurt()
# Out:
# -1.14845514534878

# %%
df['Sorting Time'].mean()
# Out:
# 6.190476190476191

# %%
df['Sorting Time'].max()
# Out:
# 10

# %%
df['Sorting Time'].min()
# Out:
# 2

# %%
df['Sorting Time'].mode()
# Out:
# 0    7
# Name: Sorting Time, dtype: int64

# %%
df['Sorting Time'].median()
# Out:
# 6.0

# %%
df['Sorting Time'].var()
# Out:
# 6.46190476190476

# %%
df['Delivery Time'].skew()
# Out:
# 0.3523900822831107

# %%
df['Delivery Time'].kurt()
# Out:
# 0.31795982942685397

# %%
df['Delivery Time'].mean()
# Out:
# 16.790952380952383

# %%
df['Delivery Time'].max()
# Out:
# 29.0

# %%
df['Delivery Time'].min()
# Out:
# 8.0

# %%
df['Delivery Time'].mode()
# Out:
# 0      8.00
# 1      9.50
# 2     10.75
# 3     11.50
# 4     12.03
# 5     13.50
# 6     13.75
# 7     14.88
# 8     15.35
# 9     16.68
# 10    17.83
# 11    17.90
# 12    18.11
# 13    18.75
# 14    19.00
# 15    19.75
# 16    19.83
# 17    21.00
# 18    21.50
# 19    24.00
# 20    29.00
# Name: Delivery Time, dtype: float64

# %%
df['Delivery Time'].median()
# Out:
# 17.83

# %%
df['Delivery Time'].var()
# Out:
# 25.754619047619048

# %%
#Correlation analysis
df.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
sns.scatterplot(df['Sorting Time'])
# Out:
# <Axes: ylabel='Sorting Time'>

# %%
sns.pairplot(df.corr())
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
sc = StandardScaler()

# %%
df.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
scaled_df = pd.DataFrame(sc.fit_transform(df),columns=df.columns)

# %%
scaled_df
# Out:
#     Delivery Time  Sorting Time
# 0        0.849867      1.535625
# 1       -0.664490     -0.882984
# 2        0.597474     -0.076781
# 3        1.455610      1.132523
# 4        2.465181      1.535625
# 5       -0.290949     -0.076781
# 6        0.446038      0.326320
# 7       -1.472148     -1.286086
# 8        0.223933      1.535625
# 9        0.395560      1.132523
# 10       0.613627      0.729422
# 11      -1.219755     -0.882984
# 12      -0.022403      0.326320
# 13      -1.068319     -1.286086
# 14      -0.961304     -1.286086
# 15      -0.385849     -0.882984
# 16      -0.614012     -0.076781
# 17       0.266335      0.326320
# 18      -1.775019     -1.689187
# 19       0.209799      0.326320
# 20       0.950824     -0.479883

# %%
scaled_df.describe()
# Out:
#        Delivery Time  Sorting Time
# count   2.100000e+01  2.100000e+01
# mean   -5.392512e-16 -7.137148e-17
# std     1.024695e+00  1.024695e+00
# min    -1.775019e+00 -1.689187e+00
# 25%    -6.644904e-01 -8.829842e-01
# 50%     2.097986e-01 -7.678123e-02
# 75%     5.974740e-01  7.294217e-01
# max     2.465181e+00  1.535625e+00

# %%
minmax = MinMaxScaler()

# %%
norm_df = pd.DataFrame(minmax.fit_transform(df),columns=df.columns)
norm_df
# Out:
#     Delivery Time  Sorting Time
# 0        0.619048         1.000
# 1        0.261905         0.250
# 2        0.559524         0.500
# 3        0.761905         0.875
# 4        1.000000         1.000
# 5        0.350000         0.500
# 6        0.523810         0.625
# 7        0.071429         0.125
# 8        0.471429         1.000
# 9        0.511905         0.875
# 10       0.563333         0.750
# 11       0.130952         0.250
# 12       0.413333         0.625
# 13       0.166667         0.125
# 14       0.191905         0.125
# 15       0.327619         0.250
# 16       0.273810         0.500
# 17       0.481429         0.625
# 18       0.000000         0.000
# 19       0.468095         0.625
# 20       0.642857         0.375

# %%
norm_df.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean        0.418617      0.523810
# std         0.241662      0.317753
# min         0.000000      0.000000
# 25%         0.261905      0.250000
# 50%         0.468095      0.500000
# 75%         0.559524      0.750000
# max         1.000000      1.000000

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
#Rename The Columns
df.rename(columns={'Delivery Time':'delivery_time','Sorting Time':'sorting_time'}, inplace=True)
df
# Out:
#     delivery_time  sorting_time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
#Import Statsmodels

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols('delivery_time~sorting_time',data=df).fit()

# %%
#ModelParameters
model.params
# Out:
# Intercept       6.582734
# sorting_time    1.649020
# dtype: float64

# %%
df.head()
# Out:
#    delivery_time  sorting_time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
#Print values for tvalue and pvalue
model.pvalues , model.tvalues
# Out:
# (Intercept       0.001147
#  sorting_time    0.000004
#  dtype: float64,
#  Intercept       3.823349
#  sorting_time    6.387447
#  dtype: float64)

# %%
model.pvalues
# Out:
# Intercept       0.001147
# sorting_time    0.000004
# dtype: float64

# %%
model.tvalues
# Out:
# Intercept       3.823349
# sorting_time    6.387447
# dtype: float64

# %%
#r2 values
model.rsquared
# Out:
# 0.6822714748417231

# %%
model.rsquared_adj
# Out:
# 0.6655489208860244

# %%
#Prediction for New Data
delivery_time = (6.582734 + 1.649020)*24
delivery_time
# Out:
# 197.562096

# %%
new_data = pd.Series([24,48])
new_data
# Out:
# 0    24
# 1    48
# dtype: int64

# %%
df_pred = pd.DataFrame(new_data,columns=['sorting_time'])
df_pred
# Out:
#    sorting_time
# 0            24
# 1            48

# %%
model.predict(df_pred)
# Out:
# 0    46.159211
# 1    85.735689
# dtype: float64

# %%
plt.subplot(1,2,1)
sns.distplot(df['delivery_time'])
plt.subplot(1,2,2)
sns.distplot(df['sorting_time'])
plt.tight_layout()

# %%
#Model Transformations - Log, Square, Sqrt, Cube, Cbrt

# %%
#Log Transformation
df.head(2)
# Out:
#    delivery_time  sorting_time
# 0           21.0            10
# 1           13.5             4

# %%
df['log_delivery_time'] = np.log(df['delivery_time'])
df['log_sorting_time'] = np.log(df['sorting_time'])

# %%
df
# Out:
#     delivery_time  sorting_time  log_delivery_time  log_sorting_time
# 0           21.00            10           3.044522          2.302585
# 1           13.50             4           2.602690          1.386294
# 2           19.75             6           2.983153          1.791759
# 3           24.00             9           3.178054          2.197225
# 4           29.00            10           3.367296          2.302585
# 5           15.35             6           2.731115          1.791759
# 6           19.00             7           2.944439          1.945910
# 7            9.50             3           2.251292          1.098612
# 8           17.90            10           2.884801          2.302585
# 9           18.75             9           2.931194          2.197225
# 10          19.83             8           2.987196          2.079442
# 11          10.75             4           2.374906          1.386294
# 12          16.68             7           2.814210          1.945910
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['log_delivery_time'])
plt.subplot(1,2,2)
sns.distplot(df['log_sorting_time'])
plt.tight_layout()

# %%
#Square Transformations

# %%
df.head(3)
# Out:
#    delivery_time  sorting_time  log_delivery_time  log_sorting_time
# 0          21.00            10           3.044522          2.302585
# 1          13.50             4           2.602690          1.386294
# 2          19.75             6           2.983153          1.791759

# %%
df['square_delivery_time'] = np.square(df['delivery_time'])
df['square_sorting_time'] = np.square(df['sorting_time'])

# %%
df
# Out:
#     delivery_time  sorting_time  log_delivery_time  log_sorting_time  \
# 0           21.00            10           3.044522          2.302585
# 1           13.50             4           2.602690          1.386294
# 2           19.75             6           2.983153          1.791759
# 3           24.00             9           3.178054          2.197225
# 4           29.00            10           3.367296          2.302585
# 5           15.35             6           2.731115          1.791759
# 6           19.00             7           2.944439          1.945910
# 7            9.50             3           2.251292          1.098612
# 8           17.90            10           2.884801          2.302585
# 9           18.75             9           2.931194          2.197225
# 10          19.83             8           2.987196          2.079442
# 11          10.75             4           2.374906          1.386294
# 12          16.68             7           2.814210          1.945910
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['square_delivery_time'])
plt.subplot(1,2,2)
sns.distplot(df['square_sorting_time'])
plt.tight_layout()

# %%
#Square Root Transformations
df.head(4)
# Out:
#    delivery_time  sorting_time  log_delivery_time  log_sorting_time  \
# 0          21.00            10           3.044522          2.302585
# 1          13.50             4           2.602690          1.386294
# 2          19.75             6           2.983153          1.791759
# 3          24.00             9           3.178054          2.197225
#
#    square_delivery_time  square_sorting_time
# 0              441.0000                  100
# 1              182.2500                   16
# 2              390.0625                   36
# 3              576.0000                   81

# %%
df['sqrt_delivery_time'] = np.sqrt(df['delivery_time'])
df['sqrt_sorting_time'] = np.sqrt(df['sorting_time'])

# %%
df
# Out:
#     delivery_time  sorting_time  log_delivery_time  log_sorting_time  \
# 0           21.00            10           3.044522          2.302585
# 1           13.50             4           2.602690          1.386294
# 2           19.75             6           2.983153          1.791759
# 3           24.00             9           3.178054          2.197225
# 4           29.00            10           3.367296          2.302585
# 5           15.35             6           2.731115          1.791759
# 6           19.00             7           2.944439          1.945910
# 7            9.50             3           2.251292          1.098612
# 8           17.90            10           2.884801          2.302585
# 9           18.75             9           2.931194          2.197225
# 10          19.83             8           2.987196          2.079442
# 11          10.75             4           2.374906          1.386294
# 12          16.68             7           2.814210          1.945910
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['sqrt_delivery_time'])
plt.subplot(1,2,2)
sns.distplot(df['sqrt_sorting_time'])
plt.tight_layout()

# %%
#Cube Root Transformations

# %%
df.head(5)
# Out:
#    delivery_time  sorting_time  log_delivery_time  log_sorting_time  \
# 0          21.00            10           3.044522          2.302585
# 1          13.50             4           2.602690          1.386294
# 2          19.75             6           2.983153          1.791759
# 3          24.00             9           3.178054          2.197225
# 4          29.00            10           3.367296          2.302585
#
#    square_delivery_time  square_sorting_time  sqrt_delivery_time  \
# 0              441.0000                  100            4.582576
# 1              182.2500                   16            3.674235
# 2              390.0625                   36            4.444097
# 3              576.0000                   81            4.898979
# 4              841.0000                  100            5.385165
#
#    sqrt_sorting_time
# 0           3.162278
# 1           2.000000
# 2           2.449490
# 3           3.000000
# 4           3.162278

# %%
df['cbrt_delivery_time'] = np.cbrt(df['delivery_time'])
df['cbrt_sorting_time'] = np.cbrt(df['sorting_time'])

# %%
df
# Out:
#     delivery_time  sorting_time  log_delivery_time  log_sorting_time  \
# 0           21.00            10           3.044522          2.302585
# 1           13.50             4           2.602690          1.386294
# 2           19.75             6           2.983153          1.791759
# 3           24.00             9           3.178054          2.197225
# 4           29.00            10           3.367296          2.302585
# 5           15.35             6           2.731115          1.791759
# 6           19.00             7           2.944439          1.945910
# 7            9.50             3           2.251292          1.098612
# 8           17.90            10           2.884801          2.302585
# 9           18.75             9           2.931194          2.197225
# 10          19.83             8           2.987196          2.079442
# 11          10.75             4           2.374906          1.386294
# 12          16.68             7           2.814210          1.945910
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['cbrt_delivery_time'])
plt.subplot(1,2,2)
sns.distplot(df['cbrt_sorting_time'])
plt.tight_layout()

# %%
df.duplicated()
df.duplicated().sum()
# Out:
# 0

# %%
df.isna()
df.isna().sum()
# Out:
# delivery_time           0
# sorting_time            0
# log_delivery_time       0
# log_sorting_time        0
# square_delivery_time    0
# square_sorting_time     0
# sqrt_delivery_time      0
# sqrt_sorting_time       0
# cbrt_delivery_time      0
# cbrt_sorting_time       0
# dtype: int64

# %%
df.hist()
plt.tight_layout()
plt.show()

# %%
df.boxplot()
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)
plt.tight_layout()
plt.show()
