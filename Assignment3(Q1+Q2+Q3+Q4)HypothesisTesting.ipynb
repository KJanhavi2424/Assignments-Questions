# %% [markdown]
# # Q1 - Cutlets.csv

# %%
#A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units. A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level. Please state the assumptions and tests that you carried out to check validity of the assumptions.

# %%
#Importing Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300
sns.set_theme(style='darkgrid',palette='rainbow')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Load The dataset
df = pd.read_csv('https://raw.githubusercontent.com/KJanhavi2424/My-Datasets/main/Cutlets.csv')
df
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
df.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
df.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
UnitB=pd.Series(df.iloc[:,1])
UnitB
# Out:
# 0     6.7703
# 1     7.5093
# 2     6.7300
# 3     6.7878
# 4     7.1522
# 5     6.8110
# 6     7.2212
# 7     6.6606
# 8     7.2402
# 9     7.0503
# 10    6.8810
# 11    7.4059
# 12    6.7652
# 13    6.0380
# 14    7.1581
# 15    7.0240
# 16    6.6672
# 17    7.4314
# 18    7.3070
# 19    6.7478
# 20    6.8889
# 21    7.4220
# 22    6.5217
# 23    7.1688
# 24    6.7594
# 25    6.9399
# 26    7.0133
# 27    6.9182
# 28    6.3346
# 29    7.5459
# 30    7.0992
# 31    7.1180
# 32    6.6965
# 33    6.5780
# 34    7.3875
# Name: Unit B, dtype: float64

# %%
UnitA=pd.Series(df.iloc[:,0])
UnitA
# Out:
# 0     6.8090
# 1     6.4376
# 2     6.9157
# 3     7.3012
# 4     7.4488
# 5     7.3871
# 6     6.8755
# 7     7.0621
# 8     6.6840
# 9     6.8236
# 10    7.3930
# 11    7.5169
# 12    6.9246
# 13    6.9256
# 14    6.5797
# 15    6.8394
# 16    6.5970
# 17    7.2705
# 18    7.2828
# 19    7.3495
# 20    6.9438
# 21    7.1560
# 22    6.5341
# 23    7.2854
# 24    6.9952
# 25    6.8568
# 26    7.2163
# 27    6.6801
# 28    6.9431
# 29    7.0852
# 30    6.7794
# 31    7.2783
# 32    7.1561
# 33    7.3943
# 34    6.9405
# Name: Unit A, dtype: float64

# %%
#2Sample 2tailTest : stats.ttest_ind(array1,array2)

# %%
#ind = Independent Samples

# %%
p_value=stats.ttest_ind(UnitA,UnitB)
p_value
# Out:
# Ttest_indResult(statistic=0.7228688704678063, pvalue=0.4722394724599501)

# %%
p_value[1]
# Out:
# 0.4722394724599501

# %%
#2Tail Probability

# %%
#Compairing p_value with alpha = 0.05(At 5% significance level)

# %%
p_value=1-stats.t.cdf(p_value[1],df=72)
p_value
# Out:
# 0.31909203848242074

# %%
alpha = 0.05
if p_value <alpha:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Fail to Reject Null Hypothesis

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.pairplot(df)
plt.tight_layout()

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
plt.pie(df['Unit A'], labels=df['Unit B'],autopct='%0.0f%%')
plt.tight_layout()
plt.show()

# %%
df.hist()
plt.tight_layout()

# %%
plt.hist(df['Unit A'],edgecolor='black')
plt.hist(df['Unit B'],edgecolor='black')
plt.tight_layout()
plt.show()

# %%
sns.heatmap(df)
plt.tight_layout()

# %%
plt.subplot(1,2,1)
sns.distplot(df['Unit A'])

plt.subplot(1,2,2)
sns.distplot(df['Unit B'])
plt.tight_layout()

# %%
pd.plotting.scatter_matrix(df)
plt.tight_layout()

# %% [markdown]
# # Q2 - LabTAT.csv

# %%
#A hospital wants to determine whether there is any difference in the average Turn Around Time (TAT) of reports of the laboratories on their preferred list. They collected a random sample and recorded TAT for reports of 4 laboratories. TAT is defined as sample collected to report dispatch.
 #Analyze the data and determine whether there is any difference in average TAT among the different laboratories at 5% significance level.

# %%
#Importing Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300
sns.set_theme(style='darkgrid',palette='rainbow')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# load the dataset
df= pd.read_csv('https://raw.githubusercontent.com/KJanhavi2424/My-Datasets/main/LabTAT.csv')
df
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
df.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
df.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
# Anova ftest statistics: stats.f_oneway(column-1,column-2,column-3,column-4)
p_value=stats.f_oneway(df.iloc[:,0],df.iloc[:,1],df.iloc[:,2],df.iloc[:,3])
p_value
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
p_value[1]
# Out:
# 2.1156708949992414e-57

# %%
p_value=1-stats.t.cdf(p_value[1],df=118)
p_value
# Out:
# 0.5

# %%
#compare the p_value with α = 0.05

# %%
alpha = 0.05
if p_value <alpha:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Fail to Reject Null Hypothesis

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.pairplot(df)
plt.tight_layout()

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
df.hist()
plt.tight_layout()

# %%
plt.hist(df['Laboratory 1'],edgecolor='black')
plt.hist(df['Laboratory 2'],edgecolor='black')
plt.hist(df['Laboratory 3'],edgecolor='black')
plt.hist(df['Laboratory 4'],edgecolor='black')
plt.tight_layout()
plt.show()

# %%
sns.heatmap(df)
plt.tight_layout()

# %%
pd.plotting.scatter_matrix(df)
plt.tight_layout()

# %% [markdown]
# # Q3 - BuyerRatio.csv

# %%
#Sales of products in four different regions is tabulated for males and females. Find if male-female buyer rations are similar across regions.

# %%
#Importing Necessary Libraries
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm
from scipy.stats import chi2_contingency

# %%
# load the dataset
data=pd.read_csv('https://raw.githubusercontent.com/KJanhavi2424/My-Datasets/main/BuyerRatio.csv')
data
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
# Make dimensional array
obs=np.array([[50,142,131,70],[435,1523,1356,750]])
obs
# Out:
# array([[  50,  142,  131,   70],
#        [ 435, 1523, 1356,  750]])

# %%
# Chi2 contengency independence test
chi2,p,dof,expected = chi2_contingency(obs)

# %%
chi2
# Out:
# 1.595945538661058

# %%
p
# Out:
# 0.6603094907091882

# %%
expected
# Out:
# array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]])

# %%
# o/p is (Chi2 stats value, p_value, df, expected obsvations)

# %%
# Compare p_value with α = 0.05

# %%
alpha = 0.05
if p <alpha:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Fail to Reject Null Hypothesis

# %% [markdown]
# # Q4 - CustomerOrderForm

# %%
#TeleCall uses 4 centers around the globe to process customer order forms. They audit a certain %  of the customer order forms. Any error in order form renders it defective and has to be reworked before processing.  The manager wants to check whether the defective %  varies by centre. Please analyze the data at 5% significance level and help the manager draw appropriate inferences

# %%
#Importing Necessary Libraries
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm
from scipy.stats import chi2_contingency

# %%
# load the dataset
df= pd.read_csv('https://raw.githubusercontent.com/KJanhavi2424/My-Datasets/main/Costomer%2BOrderForm.csv')
df
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
df.Phillippines.value_counts()
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64

# %%
df.Indonesia.value_counts()
# Out:
# Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64

# %%
df.Malta.value_counts()
# Out:
# Error Free    269
# Defective      31
# Name: Malta, dtype: int64

# %%
df.India.value_counts()
# Out:
# Error Free    280
# Defective      20
# Name: India, dtype: int64

# %%
# Making a contingency table
obs=np.array([[271,267,269,280],[29,33,31,20]])
obs
# Out:
# array([[271, 267, 269, 280],
#        [ 29,  33,  31,  20]])

# %%
# Chi2 contengency independence test
chi2,p,dof,expected = chi2_contingency(obs)

# %%
chi2
# Out:
# 3.858960685820355

# %%
p
# Out:
# 0.2771020991233135

# %%
dof
# Out:
# 3

# %%
# o/p is (Chi2 stats value, p_value, df, expected obsvations)

# %%
# Compare p_value with α = 0.05

# %%
alpha = 0.05
if p <alpha:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Fail to Reject Null Hypothesis
