# %%
#libraries import 
import pandas as pd
import numpy as np 
import seaborn as sns 
import plotly.express as pe
sns.set_theme(style='darkgrid',palette='rainbow')
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm
# %matplotlib inline

# %%
#Read dataset
df= pd.read_csv('Q7.csv')
df
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
df.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   Points      32 non-null     float64
#  2   Score       32 non-null     float64
#  3   Weigh       32 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.1+ KB

# %%
#Mean
df.mean()
# Out:
# C:\Users\Janhavi\AppData\Local\Temp\ipykernel_11632\4112407944.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
#Median
df.median()
# Out:
# C:\Users\Janhavi\AppData\Local\Temp\ipykernel_11632\1786411611.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
#Mode
df.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0           AMC Javelin    3.07   3.44  17.02
# 1    Cadillac Fleetwood    3.92    NaN  18.90
# 2            Camaro Z28     NaN    NaN    NaN
# 3     Chrysler Imperial     NaN    NaN    NaN
# 4            Datsun 710     NaN    NaN    NaN
# 5      Dodge Challenger     NaN    NaN    NaN
# 6            Duster 360     NaN    NaN    NaN
# 7          Ferrari Dino     NaN    NaN    NaN
# 8              Fiat 128     NaN    NaN    NaN
# 9             Fiat X1-9     NaN    NaN    NaN
# 10       Ford Pantera L     NaN    NaN    NaN
# 11          Honda Civic     NaN    NaN    NaN
# 12       Hornet 4 Drive     NaN    NaN    NaN
# 13    Hornet Sportabout     NaN    NaN    NaN
# 14  Lincoln Continental     NaN    NaN    NaN
# 15         Lotus Europa     NaN    NaN    NaN
# 16        Maserati Bora     NaN    NaN    NaN
# 17            Mazda RX4     NaN    NaN    NaN
# 18        Mazda RX4 Wag     NaN    NaN    NaN
# ...

# %%
#Standard Deviation
df.std()
# Out:
# C:\Users\Janhavi\AppData\Local\Temp\ipykernel_11632\65706049.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
#varience
df.var()
# Out:
# C:\Users\Janhavi\AppData\Local\Temp\ipykernel_11632\3242050757.py:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
#Range
df.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
Points_Range=df['Points'].max()-df['Points'].min()
Points_Range
# Out:
# 2.17

# %%
Score_Range=df['Score'].max()-df['Score'].min()
Score_Range
# Out:
# 3.9110000000000005

# %%
Weigh_Range=df['Weigh'].max()-df['Weigh'].min()
Weigh_Range
# Out:
# 8.399999999999999

# %%
sns.pairplot(df)
plt.tight_layout()
plt.show()

# %%
f,ax=plt.subplots(figsize=(24,18))
plt.subplot(1,3,1)
plt.boxplot(df['Points'])
plt.title('Points')
plt.subplot(1,3,2)
plt.boxplot(df['Score'])
plt.title('Score')
plt.subplot(1,3,3)
plt.boxplot(df['Weigh'])
plt.title('Weigh')
plt.show()
# Out:
# C:\Users\Janhavi\AppData\Local\Temp\ipykernel_11632\515572875.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)

# %%
plt.plot(df['Points'],color='red')
plt.show()

# %%
plt.plot(df['Score'],color='darkgreen')
plt.show()

# %%
plt.plot(df['Weigh'],color='brown')
plt.show()

# %%
plt.hist(df['Points'],edgecolor='black')
plt.axvline(df['Points'].median(),color='darkgreen')
plt.axvline(df['Points'].mean(),color='yellow')
plt.grid()

# %%
plt.hist(df['Score'],edgecolor='black')
plt.axvline(df['Score'].median(),color='yellow')
plt.axvline(df['Score'].mean(),color='red')
plt.grid()

# %%
plt.hist(df['Weigh'],edgecolor='black')
plt.axvline(df['Weigh'].median(),color='brown')
plt.axvline(df['Weigh'].mean(),color='yellow')
plt.grid()
